# %% [markdown]
# # Final project

# %% [markdown]
# problem statment - Preadicting House Price (california)
#
# On real world data set
#
# <img src = "https://www.appliedaicourse.com/blog/wp-content/uploads/2025/01/House-Price-Prediction-Using-Machine-Learning.png">

# %% [markdown]
# ### California House Price Prediction Project

# %% [markdown]
# ### Objective
# > The objective of this project is to build a multiple linear regression model that predicts the median house value in California districts based on variousfeatures like median income, housing median age, and average room counts.
#
# #### Machine Learning Pipeline
#
# * Data Collection and Import
# * Exploratory Data Analysis & Data Cleaning (Handling Nulls and Duplicates)
# * Feature Selection & Data Splitting
# * Feature Scaling (Standardization)
# * Model Building & Training
# * Model Evaluation

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# # Step 1: Data Collection and Import
# # Load the dataset from a URL or local file path

# %%
data_url = "https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/housing/housing.csv"
df = pd.read_csv(data_url)

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.7 MB

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df.shape
# Out:
# (20640, 10)

# %% [markdown]
# > in the feature called
# "Total_bedroom" we have null value we need to fix it (mean/median)

# %%
# checking duplicates 

duplicates=df.duplicated().sum()
print("Number of Duplicates rows::" + str(duplicates))
# Out:
# Number of Duplicates rows::0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.7 MB

# %%
# Handle missing values: Fill missing 'total_bedrooms' with the median of that column
median_bedrooms = df["total_bedrooms"].median()
median_bedrooms
# Out:
# np.float64(435.0)

# %%
df.fillna(median_bedrooms,inplace=True)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.7 MB

# %%
df["total_bedrooms"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Enhancing the Model: One-Hot Encoding and Feature Engineering

# %%
# Reload the dataset to include 'ocean_proximity' for one-hot encoding
df = pd.read_csv(data_url)

# Handle missing 'total_bedrooms' again after reloading
median_bedrooms = df["total_bedrooms"].median()
df["total_bedrooms"] = df["total_bedrooms"].fillna(median_bedrooms)

# %% [markdown]
# #### One-Hot Encoding for 'ocean_proximity'

# %%
### Enhancing the Model: One-Hot Encoding and Feature Engineering
# Apply one-hot encoding to 'ocean_proximity'

df_encoded =  pd.get_dummies(df, columns=['ocean_proximity'])
df_encoded.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 0                      False                   False                   False
# 1                      False                   False                   False
# 2                      False                   False                   False
# 3                      False                   False                   False
# 4                      False                   False                   False
#
#    ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN
# 0                      True                       False
# 1                      True                       False
# 2                      True                       False
# 3                      True                       False
# 4                      True                       False

# %% [markdown]
# #### Done with data preparation
#
#
# > creating new feature based on other featurer (columns)

# %%
df_encoded.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 14 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   longitude                   20640 non-null  float64
#  1   latitude                    20640 non-null  float64
#  2   housing_median_age          20640 non-null  float64
#  3   total_rooms                 20640 non-null  float64
#  4   total_bedrooms              20640 non-null  float64
#  5   population                  20640 non-null  float64
#  6   households                  20640 non-null  float64
#  7   median_income               20640 non-null  float64
#  8   median_house_value          20640 non-null  float64
#  9   ocean_proximity_<1H OCEAN   20640 non-null  bool
#  10  ocean_proximity_INLAND      20640 non-null  bool
#  11  ocean_proximity_ISLAND      20640 non-null  bool
#  12  ocean_proximity_NEAR BAY    20640 non-null  bool
#  13  ocean_proximity_NEAR OCEAN  20640 non-null  bool
# dtypes: bool(5), float64(9)
# memory usage: 1.5 MB

# %%
# Create new features
df_encoded['rooms_per_household'] = df_encoded['total_rooms'] / df_encoded['households']
df_encoded['bedrooms_per_room'] = df_encoded['total_bedrooms'] / df_encoded['total_rooms']
df_encoded['population_per_household'] = df_encoded['population'] / df_encoded['households']

df_encoded.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0         8.3252            452600.0
# 1      2401.0      1138.0         8.3014            358500.0
# 2       496.0       177.0         7.2574            352100.0
# 3       558.0       219.0         5.6431            341300.0
# 4       565.0       259.0         3.8462            342200.0
#
#    ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 0                      False                   False                   False
# 1                      False                   False                   False
# 2                      False                   False                   False
# 3                      False                   False                   False
# 4                      False                   False                   False
#
#    ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN  rooms_per_household  \
# 0                      True                       False             6.984127
# 1                      True                       False             6.238137
# 2                      True                       False             8.288136
# 3                      True                       False             5.817352
# 4                      True                       False             6.281853
#
#    bedrooms_per_room  population_per_household
# 0           0.146591                  2.555556
# 1           0.155797                  2.109842
# 2           0.129516                  2.802260
# 3           0.184458                  2.547945
# 4           0.172096                  2.181467

# %%
df_encoded.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   longitude                   20640 non-null  float64
#  1   latitude                    20640 non-null  float64
#  2   housing_median_age          20640 non-null  float64
#  3   total_rooms                 20640 non-null  float64
#  4   total_bedrooms              20640 non-null  float64
#  5   population                  20640 non-null  float64
#  6   households                  20640 non-null  float64
#  7   median_income               20640 non-null  float64
#  8   median_house_value          20640 non-null  float64
#  9   ocean_proximity_<1H OCEAN   20640 non-null  bool
#  10  ocean_proximity_INLAND      20640 non-null  bool
#  11  ocean_proximity_ISLAND      20640 non-null  bool
#  12  ocean_proximity_NEAR BAY    20640 non-null  bool
#  13  ocean_proximity_NEAR OCEAN  20640 non-null  bool
#  14  rooms_per_household         20640 non-null  float64
#  15  bedrooms_per_room           20640 non-null  float64
#  16  population_per_household    20640 non-null  float64
# dtypes: bool(5), float64(12)
# memory usage: 2.0 MB

# %% [markdown]
# ## vertical split (To seprate input and output)

# %%
X=df_encoded.drop(columns="median_house_value")

# %%
X
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  ocean_proximity_<1H OCEAN  \
# 0           322.0       126.0         8.3252                      False
# 1          2401.0      1138.0         8.3014                      False
# 2           496.0       177.0         7.2574                      False
# 3           558.0       219.0         5.6431                      False
# 4           565.0       259.0         3.8462                      False
# ...           ...         ...            ...                        ...
# 20635       845.0       330.0         1.5603                      False
# 20636       356.0       114.0         2.5568                      False
# 20637      1007.0       433.0         1.7000                      False
# 20638       741.0       349.0         1.8672                      False
# 20639      1387.0       530.0         2.3886                      False
#
#        ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 0                       False                   False
# 1                       False                   False
# 2                       False                   False
# 3                       False                   False
# 4                       False                   False
# ...                       ...                     ...
# 20635                    True                   False
# 20636                    True                   False
# 20637                    True                   False
# 20638                    True                   False
# 20639                    True                   False
#
#        ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN  \
# 0                          True                       False
# 1                          True                       False
# 2                          True                       False
# 3                          True                       False
# 4                          True                       False
# ...                         ...                         ...
# 20635                     False                       False
# 20636                     False                       False
# 20637                     False                       False
# 20638                     False                       False
# 20639                     False                       False
#
#        rooms_per_household  bedrooms_per_room  population_per_household
# 0                 6.984127           0.146591                  2.555556
# 1                 6.238137           0.155797                  2.109842
# 2                 8.288136           0.129516                  2.802260
# 3                 5.817352           0.184458                  2.547945
# 4                 6.281853           0.172096                  2.181467
# ...                    ...                ...                       ...
# 20635             5.045455           0.224625                  2.560606
# 20636             6.114035           0.215208                  3.122807
# 20637             5.205543           0.215173                  2.325635
# 20638             5.329513           0.219892                  2.123209
# 20639             5.254717           0.221185                  2.616981
#
# [20640 rows x 16 columns]

# %%
X.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'ocean_proximity_<1H OCEAN', 'ocean_proximity_INLAND',
#        'ocean_proximity_ISLAND', 'ocean_proximity_NEAR BAY',
#        'ocean_proximity_NEAR OCEAN', 'rooms_per_household',
#        'bedrooms_per_room', 'population_per_household'],
#       dtype='str')

# %%
Y=df_encoded['median_house_value'] # o/p

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  str
# dtypes: float64(9), str(1)
# memory usage: 1.7 MB

# %% [markdown]
# ## horizontal split

# %%
# Split the data into training (80%) and testing (20%) sets
X_train_new, X_test_new, y_train_new, y_test_new = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train_new
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.03     32.71                33.0       3126.0           627.0
# 8267     -118.16     33.77                49.0       3382.0           787.0
# 17445    -120.48     34.66                 4.0       1897.0           331.0
# 14265    -117.11     32.69                36.0       1421.0           367.0
# 2271     -119.80     36.78                43.0       2382.0           431.0
# ...          ...       ...                 ...          ...             ...
# 11284    -117.96     33.78                35.0       1330.0           201.0
# 11964    -117.43     34.02                33.0       3084.0           570.0
# 5390     -118.38     34.03                36.0       2101.0           569.0
# 860      -121.96     37.58                15.0       3575.0           597.0
# 15795    -122.42     37.77                52.0       4226.0          1315.0
#
#        population  households  median_income  ocean_proximity_<1H OCEAN  \
# 14196      2300.0       623.0         3.2596                      False
# 8267       1314.0       756.0         3.8125                      False
# 17445       915.0       336.0         4.1563                      False
# 14265      1418.0       355.0         1.9425                      False
# 2271        874.0       380.0         3.5542                      False
# ...           ...         ...            ...                        ...
# 11284       658.0       217.0         6.3700                       True
# 11964      1753.0       449.0         3.0500                      False
# 5390       1756.0       527.0         2.9344                       True
# 860        1777.0       559.0         5.7192                       True
# 15795      2619.0      1242.0         2.5755                      False
#
#        ocean_proximity_INLAND  ocean_proximity_ISLAND  \
# 14196                   False                   False
# 8267                    False                   False
# 17445                   False                   False
# 14265                   False                   False
# 2271                     True                   False
# ...                       ...                     ...
# 11284                   False                   False
# 11964                    True                   False
# 5390                    False                   False
# 860                     False                   False
# 15795                   False                   False
#
#        ocean_proximity_NEAR BAY  ocean_proximity_NEAR OCEAN  \
# 14196                     False                        True
# 8267                      False                        True
# 17445                     False                        True
# 14265                     False                        True
# 2271                      False                       False
# ...                         ...                         ...
# 11284                     False                       False
# 11964                     False                       False
# 5390                      False                       False
# 860                       False                       False
# 15795                      True                       False
#
#        rooms_per_household  bedrooms_per_room  population_per_household
# 14196             5.017657           0.200576                  3.691814
# 8267              4.473545           0.232703                  1.738095
# 17445             5.645833           0.174486                  2.723214
# 14265             4.002817           0.258269                  3.994366
# 2271              6.268421           0.180940                  2.300000
# ...                    ...                ...                       ...
# 11284             6.129032           0.151128                  3.032258
# 11964             6.868597           0.184825                  3.904232
# 5390              3.986717           0.270823                  3.332068
# 860               6.395349           0.166993                  3.178891
# 15795             3.402576           0.311169                  2.108696
#
# [16512 rows x 16 columns]

# %%
from sklearn.preprocessing import StandardScaler
# Initialize the StandardScaler
scaler_new = StandardScaler()

# Fit and transform the training features
X_train_scaled_new = scaler_new.fit_transform(X_train_new) ## mean and sd

# Transform the testing features using the training set scaler
X_test_scaled_new = scaler_new.transform(X_test_new) # mean and sd

# %% [markdown]
# #### we need to  do standasization

# %%
### use the regression model 

from sklearn.linear_model import LinearRegression

lr=LinearRegression()

# %%
lr.fit(X_train_scaled_new,y_train_new)
# Out:
# LinearRegression()

# %%
pd.DataFrame(X_test_scaled_new).info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4128 entries, 0 to 4127
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       4128 non-null   float64
#  1   1       4128 non-null   float64
#  2   2       4128 non-null   float64
#  3   3       4128 non-null   float64
#  4   4       4128 non-null   float64
#  5   5       4128 non-null   float64
#  6   6       4128 non-null   float64
#  7   7       4128 non-null   float64
#  8   8       4128 non-null   float64
#  9   9       4128 non-null   float64
#  10  10      4128 non-null   float64
#  11  11      4128 non-null   float64
#  12  12      4128 non-null   float64
#  13  13      4128 non-null   float64
#  14  14      4128 non-null   float64
#  15  15      4128 non-null   float64
# dtypes: float64(16)
# memory usage: 516.1 KB

# %%
y_predict = lr.predict(X_test_scaled_new)

# %%
### model evaluation 
from sklearn.metrics import r2_score,root_mean_squared_error
print("RMSE:",root_mean_squared_error(y_test_new,y_predict))
print("R2_Score:",r2_score(y_test_new,y_predict))
# Out:
# RMSE: 72668.53837868225
# R2_Score: 0.5970176824350764

# %% [markdown]
# ## Change the model to RandomForesetRegression

# %% [markdown]
# ## random forest Regression
#
# > ensable learning algorithm
#
# > model used = decision tree
#
# > for classification - maj
#
# > for regression - avg
#
# <img src = "https://www.slideteam.net/media/catalog/product/cache/1280x720/f/r/framework_of_random_forest_regression_algorithm_ppt_sample_slide01.jpg">

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, random_state=42) 
rf.fit(X_train_scaled_new,y_train_new)
rfpredict = rf.predict(X_test_scaled_new)
print("RMSE:",root_mean_squared_error(y_test_new,rfpredict))
print("R2_Score:",r2_score(y_test_new,rfpredict))
# Out:
# RMSE: 50368.15768695257
# R2_Score: 0.8064000361029778

# %%
import pickle

pickle.dump(rf,open("rfmodel.pkl","wb"))

# %% [markdown]
# >> Random Forest  Regressor has higher performance compare to Linear Regression
